# %%
import pandas as pd
from thunderpack import ThunderReader
from tqdm import tqdm
import re
import glob

# %% [markdown]
# # Create Feature Matrix Format
# - include info from cohort, add annotations column
# - add icd feature which includes those with pos ICD +/- 6 months of Note Date

# %% [markdown]
# ### Combined Cohort
#  - run this for combined hospital cohort

# %%
# create basic frame for feature matrix
# create list of all patient IDs that were used in annotation
cohort = pd.read_csv('/home/jsearle/bigDrive/NAX/NLP-SAH_identification/test&trainCohorts/combined_cohort_test.csv')

# read in annotations
annotations = pd.read_csv('/home/jsearle/bigDrive/NAX/NLP-SAH_identification/annotationTools/cleanAnnotations/full_annotations_final.csv')

print(len(cohort))
print(len(annotations))
# Out:
# 1548
# 3096

# %%
startMatrix = cohort.merge(annotations, left_on='BDSPPatientID', right_on='empi', how='inner')
print(len(startMatrix))
startMatrix.head()
# Out:
# 1548
#    BDSPPatientID             NoteDate  \
# 0      115883980           2018-04-14
# 1      116483510  2022-05-12 00:00:00
# 2      150009858           2013-08-29
# 3      150009896           2022-02-04
# 4      116023288  2022-01-03 00:00:00
#
#                                    NoteTitle  \
# 0  Notes_13414009311_1956375582_20180414.txt
# 1  Notes_13622415618_8165687294_20220512.txt
# 2   Notes_1129868316_2608699887_20130829.txt
# 3   Notes_1129868625_2609280946_20220204.txt
# 4  Notes_13528991310_6365444126_20220103.txt
#
#                                                 text hospital       empi  \
# 0    Physician ***** *****       Admit date: ****...      MGB  115883980
# 1    Physician ***** *****       Admit date: ****...      MGB  116483510
# 2  \n\nNote Date: *****/*****/*****\n\nNote Type:...    BIDMC  150009858
# 3  \n\nNote Date: *****/*****/*****  Time: 0813\n...    BIDMC  150009896
# 4      *****  *****    ***** Medical Psychiatry D...      MGB  116023288
#
#    annot
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0

# %%
matrix = startMatrix.drop(columns=['empi'])
matrix.head()
# Out:
#    BDSPPatientID             NoteDate  \
# 0      115883980           2018-04-14
# 1      116483510  2022-05-12 00:00:00
# 2      150009858           2013-08-29
# 3      150009896           2022-02-04
# 4      116023288  2022-01-03 00:00:00
#
#                                    NoteTitle  \
# 0  Notes_13414009311_1956375582_20180414.txt
# 1  Notes_13622415618_8165687294_20220512.txt
# 2   Notes_1129868316_2608699887_20130829.txt
# 3   Notes_1129868625_2609280946_20220204.txt
# 4  Notes_13528991310_6365444126_20220103.txt
#
#                                                 text hospital  annot
# 0    Physician ***** *****       Admit date: ****...      MGB      1
# 1    Physician ***** *****       Admit date: ****...      MGB      0
# 2  \n\nNote Date: *****/*****/*****\n\nNote Type:...    BIDMC      1
# 3  \n\nNote Date: *****/*****/*****  Time: 0813\n...    BIDMC      1
# 4      *****  *****    ***** Medical Psychiatry D...      MGB      0

# %% [markdown]
# ## MGB ICDs

# %%
path = '/home/jsearle/bigDrive/NAX/NLP-SAH_identification/cohortExtractionPipeline/MGB/CSVs/'

patientIDs = matrix['BDSPPatientID']
print(len(patientIDs))
# Out:
# 1548

# %%
csv_files = glob.glob(path + "filtered_ICD_partition_*.csv")

# %%
filtered_dfs = []

for file in tqdm(csv_files):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file)
    
    # Filter the DataFrame to include only rows with matching BDSPPatientID
    filtered_df = df[df['BDSPPatientID'].isin(patientIDs)]
    
    # Append the filtered DataFrame to the list
    filtered_dfs.append(filtered_df)

# Concatenate all filtered DataFrames into one
relevantPatientICDs = pd.concat(filtered_dfs, ignore_index=True)

relevantPatientICDs.head()
# Out:
# 100%|██████████| 511/511 [02:40<00:00,  3.19it/s]
#    BDSPEncounterID  EncounterLineNBR  BDSPPatientID  \
# 0     1.344264e+10                 3    118526681.0
# 1     1.340613e+10                 2    111886016.0
# 2     1.356705e+10                 1    117562273.0
# 3     1.345834e+10                 1    119565757.0
# 4     1.328063e+10                 2    122057217.0
#
#              ShiftedContactDTS  ICDLineNBR   ICDCD  \
# 0  2020-10-03 00:00:00.0000000         1.0     486
# 1  2018-12-31 00:00:00.0000000         1.0   272.4
# 2  2023-07-11 00:00:00.0000000         1.0   351.9
# 3  2020-01-06 00:00:00.0000000         1.0  854.06
# 4  2018-02-26 00:00:00.0000000         1.0  787.20
#
#                                               ICDDSC  \
# 0                    Pneumonia, organism unspecified
# 1               Other and unspecified hyperlipidemia
# 2                 Facial nerve disorder, unspecified
# 3  Intracranial injury of other and unspecified n...
# 4                             Dysphagia, unspecified
#
#                                          DiagnosisNM DiagnosisDSC  \
# 0  Pneumonia of both lower lobes due to infectiou...          NaN
# 1    Hyperlipidemia, unspecified hyperlipidemia type          NaN
# 2                              Facial nerve disorder          NaN
# 3  Traumatic brain injury with loss of consciousn...          NaN
# 4                        Dysphagia, unspecified type          NaN
#
#   PrimaryDiagnosisFLG DiagnosisChronicFLG             ShiftedUpdateDTS  \
# 0                   N                   N  2020-10-23 14:16:00.0000000
# 1                   N                   N  2018-12-31 13:13:00.0000000
# 2                   Y                   N  2023-07-11 20:10:00.0000000
# 3                   Y                   N  2020-01-06 13:13:00.0000000
# 4                   N                   N  2023-11-07 17:34:00.0000000
#
#    DiagnosisLinkedProblemID          BDSPLastModifiedDTS code_type
# 0                86181325.0  2022-04-27 13:04:38.9700000       ICD
# 1                30182803.0  2022-04-27 13:27:03.6830000       ICD
# 2                       NaN  2022-09-25 07:01:48.2070000       ICD
# 3                79494062.0  2022-04-27 15:51:06.4400000       ICD
# 4                41582426.0  2023-08-15 18:43:12.0060000       ICD

# %%
# Save the combined DataFrame to a new CSV file
relevantPatientICDs.to_csv("helperCSVs/MGBrelevantPatientICDs.csv", index=False)

# %% [markdown]
# ## BIDMC ICDs

# %%
path = '/home/jsearle/bigDrive/NAX/NLP-SAH_identification/cohortExtractionPipeline/BIDMC/CSVs/'

patientIDs = matrix['BDSPPatientID']
print(len(patientIDs))
# Out:
# 1548

# %%
csv_files = glob.glob(path + "filtered_ICD_partition_*.csv")

# %%
filtered_dfs = []

for file in tqdm(csv_files):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file)
    
    # Filter the DataFrame to include only rows with matching BDSPPatientID
    filtered_df = df[df['BDSPPatientID'].isin(patientIDs)]
    
    # Append the filtered DataFrame to the list
    filtered_dfs.append(filtered_df)

# Concatenate all filtered DataFrames into one
relevantPatientICDs = pd.concat(filtered_dfs, ignore_index=True)

relevantPatientICDs.head()
# Out:
#   8%|▊         | 3/36 [00:09<01:41,  3.06s/it]/tmp/ipykernel_13403/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  11%|█         | 4/36 [00:12<01:32,  2.90s/it]/tmp/ipykernel_13403/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  14%|█▍        | 5/36 [00:15<01:32,  2.99s/it]/tmp/ipykernel_13403/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  22%|██▏       | 8/36 [00:24<01:21,  2.91s/it]/tmp/ipykernel_13403/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  33%|███▎      | 12/36 [00:36<01:13,  3.07s/it]/tmp/ipykernel_13403/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  50%|█████     | 18/36 [00:53<00:52,  2.89s/it]/tmp/ipykernel_13403/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  81%|████████  | 29/36 [01:27<00:19,  2.77s/it]/tmp/ipykernel_13403/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# 100%|██████████| 36/36 [01:47<00:00,  2.99s/it]
#    BDSPPatientID  BDSPEncounterID  DiagnosisSequenceNumber DiagnosisCode  \
# 0      151039569       1051843626                        1       C50311
# 1      151039569       1051845284                        1       C50311
# 2      151039569       1051848011                        1       C50311
# 3      151039569       1051849298                        1       C50311
# 4      151039569       1051850966                        1       C50311
#
#   DiagnosisPoaInd DiagnosisCodeWithDots                     ShortDescription  \
# 0             NaN               C50.311  MAL NEO LW-INNER QUAD RT
# 1             NaN               C50.311  MAL NEO LW-INNER QUAD RT
# 2             NaN               C50.311  MAL NEO LW-INNER QUAD RT
# 3             NaN               C50.311  MAL NEO LW-INNER QUAD RT
# 4             NaN               C50.311  MAL NEO LW-INNER QUAD RT
#
#                                      LongDescription DiagnosisType  \
# 0  MALIG NEOPLM OF LOWER-INNER QUADRANT OF RIGHT ...         ICD10
# 1  MALIG NEOPLM OF LOWER-INNER QUADRANT OF RIGHT ...         ICD10
# 2  MALIG NEOPLM OF LOWER-INNER QUADRANT OF RIGHT ...         ICD10
# 3  MALIG NEOPLM OF LOWER-INNER QUADRANT OF RIGHT ...         ICD10
# 4  MALIG NEOPLM OF LOWER-INNER QUADRANT OF RIGHT ...         ICD10
#
#   AdmissionDate DischargeDate          BDSPLastModifiedDTS code_type
# 0    2016-11-21    2016-11-21  2023-07-19 19:09:12.4626110     ICD10
# 1    2016-11-22    2016-11-22  2023-07-19 19:09:12.4626110     ICD10
# 2    2016-11-23    2016-11-23  2023-07-19 19:09:12.4626110     ICD10
# 3    2016-11-26    2016-11-26  2023-07-19 19:09:12.4626110     ICD10
# 4    2016-11-27    2016-11-27  2023-07-19 19:09:12.4626110     ICD10

# %%
# Save the combined DataFrame to a new CSV file
relevantPatientICDs.to_csv("helperCSVs/BIDMCrelevantPatientICDs.csv", index=False)

# %% [markdown]
# # Create new csv that filters by ICD code
# ### MGB First

# %%
MGBrelevantPatientICDs = pd.read_csv("helperCSVs/MGBrelevantPatientICDs.csv")
BIDMCrelevantPatientICDs = pd.read_csv("helperCSVs/BIDMCrelevantPatientICDs.csv")

# %%
code_regex = '^(I60|430)'

MGBrelevantPatientICDs = MGBrelevantPatientICDs.dropna(subset=['ICDCD'])

allPosICDsMGB = MGBrelevantPatientICDs[MGBrelevantPatientICDs['ICDCD'].str.match(code_regex)]

allPosICDsMGB.head()
# Out:
#      BDSPEncounterID  EncounterLineNBR  BDSPPatientID  \
# 202     1.372123e+10                 4    121501383.0
# 207     1.361430e+10                 2    113797450.0
# 273     1.368807e+10                 1    113270682.0
# 281     1.358875e+10                 1    120491495.0
# 438     1.368526e+10                 1    116587087.0
#
#                ShiftedContactDTS  ICDLineNBR ICDCD                   ICDDSC  \
# 202  2022-07-03 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 207  2021-06-22 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 273  2023-09-19 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 281  2023-03-07 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 438  2022-10-20 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
#
#                                  DiagnosisNM DiagnosisDSC PrimaryDiagnosisFLG  \
# 202                  Subarachnoid hemorrhage          NaN                   N
# 207  Ruptured (congenital) cerebral aneurysm          NaN                   N
# 273                  Subarachnoid hemorrhage          NaN                   N
# 281                Cerebral aneurysm rupture          NaN                   N
# 438            SAH (subarachnoid hemorrhage)          NaN                   Y
#
#     DiagnosisChronicFLG             ShiftedUpdateDTS  \
# 202                   N  2022-07-04 23:08:00.0000000
# 207                   N  2021-06-22 18:14:00.0000000
# 273                   N  2023-09-19 16:24:00.0000000
# 281                   N  2023-03-07 10:47:00.0000000
# 438                   N  2022-11-17 13:20:00.0000000
#
#      DiagnosisLinkedProblemID          BDSPLastModifiedDTS code_type
# 202               127299861.0  2022-09-15 07:00:26.8080000       ICD
# 207               112494133.0  2022-06-13 17:43:46.0660000       ICD
# 273               102014310.0  2023-08-16 07:08:36.4310000       ICD
# 281                91821754.0  2022-08-17 06:09:29.6700000       ICD
# 438               124551050.0  2022-06-13 17:47:33.6620000       ICD

# %%
BIDMCrelevantPatientICDs = BIDMCrelevantPatientICDs.dropna(subset=['DiagnosisCodeWithDots'])

allPosICDsBIDMC = BIDMCrelevantPatientICDs[BIDMCrelevantPatientICDs['DiagnosisCodeWithDots'].str.match(code_regex)]

allPosICDsBIDMC.head()
# Out:
#      BDSPPatientID  BDSPEncounterID  DiagnosisSequenceNumber DiagnosisCode  \
# 209      151055839        134384936                        1       I6012
# 299      151055679        134606361                        1       I608
# 309      151055679        134622230                        1       I609
# 349      151055679        562955858                        1       I608
# 520      151055839        984158717                        1       I609
#
#     DiagnosisPoaInd DiagnosisCodeWithDots  \
# 209               Y                I60.12
# 299               Y                 I60.8
# 309             NaN                 I60.9
# 349               Y                 I60.8
# 520             NaN                 I60.9
#
#                         ShortDescription  \
# 209  NONTRAUM SA HEMOR LT MID
# 299  OTH NONTRAUM SUBARACHNOI
# 309  NONTRAUMATIC SUBARACH HE
# 349  OTH NONTRAUM SUBARACHNOI
# 520  NONTRAUMATIC SUBARACH HE
#
#                                        LongDescription DiagnosisType  \
# 209  NTRM SUBARACH HEMORRHAGE FROM LEFT MIDDLE CERE...         ICD10
# 299  OTHER NONTRAUMATIC SUBARACHNOID HEMORRHAGE    ...         ICD10
# 309  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
# 349  OTHER NONTRAUMATIC SUBARACHNOID HEMORRHAGE    ...         ICD10
# 520  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
#
#     AdmissionDate DischargeDate          BDSPLastModifiedDTS code_type
# 209    2018-05-18    2018-06-05  2023-07-19 19:10:23.4213520     ICD10
# 299    2019-12-17    2019-12-24  2023-07-19 19:10:23.4213520     ICD10
# 309    2020-03-16    2020-03-16  2023-07-19 19:10:23.4213520     ICD10
# 349    2019-12-17    2019-12-17  2023-07-19 19:10:23.4213520     ICD10
# 520    2018-09-16    2018-09-16  2023-07-19 19:10:23.4213520     ICD10

# %%
allPosICDsMGB.to_csv("helperCSVs/allPosICDsMGB.csv", index=False)
allPosICDsBIDMC.to_csv("helperCSVs/allPosICDsBIDMC.csv", index=False)

# %% [markdown]
# ## Now adding feature for ICD code received 6 months +/- the NoteDate

# %%
allPosICDsMGB = pd.read_csv('helperCSVs/allPosICDsMGB.csv')
allPosICDsBIDMC = pd.read_csv('helperCSVs/allPosICDsBIDMC.csv')

# %%
# Rename the date columns to a common name
allPosICDsMGB = allPosICDsMGB.rename(columns={'ShiftedContactDTS': 'ICDDate'})
allPosICDsBIDMC = allPosICDsBIDMC.rename(columns={'AdmissionDate': 'ICDDate'})

# %%
allPosICDsMGB.head()
# Out:
#    BDSPEncounterID  EncounterLineNBR  BDSPPatientID  \
# 0     1.372123e+10                 4    121501383.0
# 1     1.361430e+10                 2    113797450.0
# 2     1.368807e+10                 1    113270682.0
# 3     1.358875e+10                 1    120491495.0
# 4     1.368526e+10                 1    116587087.0
#
#                        ICDDate  ICDLineNBR ICDCD                   ICDDSC  \
# 0  2022-07-03 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 1  2021-06-22 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 2  2023-09-19 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 3  2023-03-07 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 4  2022-10-20 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
#
#                                DiagnosisNM  DiagnosisDSC PrimaryDiagnosisFLG  \
# 0                  Subarachnoid hemorrhage           NaN                   N
# 1  Ruptured (congenital) cerebral aneurysm           NaN                   N
# 2                  Subarachnoid hemorrhage           NaN                   N
# 3                Cerebral aneurysm rupture           NaN                   N
# 4            SAH (subarachnoid hemorrhage)           NaN                   Y
#
#   DiagnosisChronicFLG             ShiftedUpdateDTS  DiagnosisLinkedProblemID  \
# 0                   N  2022-07-04 23:08:00.0000000               127299861.0
# 1                   N  2021-06-22 18:14:00.0000000               112494133.0
# 2                   N  2023-09-19 16:24:00.0000000               102014310.0
# 3                   N  2023-03-07 10:47:00.0000000                91821754.0
# 4                   N  2022-11-17 13:20:00.0000000               124551050.0
#
#            BDSPLastModifiedDTS code_type
# 0  2022-09-15 07:00:26.8080000       ICD
# 1  2022-06-13 17:43:46.0660000       ICD
# 2  2023-08-16 07:08:36.4310000       ICD
# 3  2022-08-17 06:09:29.6700000       ICD
# 4  2022-06-13 17:47:33.6620000       ICD

# %%
allPosICDsBIDMC.head()
# Out:
#    BDSPPatientID  BDSPEncounterID  DiagnosisSequenceNumber DiagnosisCode  \
# 0      151055839        134384936                        1       I6012
# 1      151055679        134606361                        1       I608
# 2      151055679        134622230                        1       I609
# 3      151055679        562955858                        1       I608
# 4      151055839        984158717                        1       I609
#
#   DiagnosisPoaInd DiagnosisCodeWithDots                     ShortDescription  \
# 0               Y                I60.12  NONTRAUM SA HEMOR LT MID
# 1               Y                 I60.8  OTH NONTRAUM SUBARACHNOI
# 2             NaN                 I60.9  NONTRAUMATIC SUBARACH HE
# 3               Y                 I60.8  OTH NONTRAUM SUBARACHNOI
# 4             NaN                 I60.9  NONTRAUMATIC SUBARACH HE
#
#                                      LongDescription DiagnosisType  \
# 0  NTRM SUBARACH HEMORRHAGE FROM LEFT MIDDLE CERE...         ICD10
# 1  OTHER NONTRAUMATIC SUBARACHNOID HEMORRHAGE    ...         ICD10
# 2  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
# 3  OTHER NONTRAUMATIC SUBARACHNOID HEMORRHAGE    ...         ICD10
# 4  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
#
#       ICDDate DischargeDate          BDSPLastModifiedDTS code_type
# 0  2018-05-18    2018-06-05  2023-07-19 19:10:23.4213520     ICD10
# 1  2019-12-17    2019-12-24  2023-07-19 19:10:23.4213520     ICD10
# 2  2020-03-16    2020-03-16  2023-07-19 19:10:23.4213520     ICD10
# 3  2019-12-17    2019-12-17  2023-07-19 19:10:23.4213520     ICD10
# 4  2018-09-16    2018-09-16  2023-07-19 19:10:23.4213520     ICD10

# %%
allPosICDsMGB['ICDDate'] = pd.to_datetime(allPosICDsMGB['ICDDate'])
allPosICDsBIDMC['ICDDate'] = pd.to_datetime(allPosICDsBIDMC['ICDDate'])

# %%
icd_df = pd.concat([allPosICDsMGB, allPosICDsBIDMC], ignore_index=True)

# %%
matrix = startMatrix

# %%
def parse_dates(date_str):
    for fmt in ('%Y-%m-%d %H:%M:%S.%f', '%Y-%m-%d %H:%M:%S', '%Y-%m-%d'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue
    # If all formats fail, return NaT
    return pd.NaT

# Apply the custom function to convert dates
matrix['NoteDate'] = matrix['NoteDate'].apply(parse_dates)
matrix.head()
# Out:
#    BDSPPatientID   NoteDate                                  NoteTitle  \
# 0      115883980 2018-04-14  Notes_13414009311_1956375582_20180414.txt
# 1      116483510 2022-05-12  Notes_13622415618_8165687294_20220512.txt
# 2      150009858 2013-08-29   Notes_1129868316_2608699887_20130829.txt
# 3      150009896 2022-02-04   Notes_1129868625_2609280946_20220204.txt
# 4      116023288 2022-01-03  Notes_13528991310_6365444126_20220103.txt
#
#                                                 text hospital       empi  \
# 0    Physician ***** *****       Admit date: ****...      MGB  115883980
# 1    Physician ***** *****       Admit date: ****...      MGB  116483510
# 2  \n\nNote Date: *****/*****/*****\n\nNote Type:...    BIDMC  150009858
# 3  \n\nNote Date: *****/*****/*****  Time: 0813\n...    BIDMC  150009896
# 4      *****  *****    ***** Medical Psychiatry D...      MGB  116023288
#
#    annot
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0

# %%
matrix = matrix.drop(columns=['empi'])
matrix.head()
# Out:
#    BDSPPatientID   NoteDate                                  NoteTitle  \
# 0      115883980 2018-04-14  Notes_13414009311_1956375582_20180414.txt
# 1      116483510 2022-05-12  Notes_13622415618_8165687294_20220512.txt
# 2      150009858 2013-08-29   Notes_1129868316_2608699887_20130829.txt
# 3      150009896 2022-02-04   Notes_1129868625_2609280946_20220204.txt
# 4      116023288 2022-01-03  Notes_13528991310_6365444126_20220103.txt
#
#                                                 text hospital  annot
# 0    Physician ***** *****       Admit date: ****...      MGB      1
# 1    Physician ***** *****       Admit date: ****...      MGB      0
# 2  \n\nNote Date: *****/*****/*****\n\nNote Type:...    BIDMC      1
# 3  \n\nNote Date: *****/*****/*****  Time: 0813\n...    BIDMC      1
# 4      *****  *****    ***** Medical Psychiatry D...      MGB      0

# %%
matrix['NoteDate'] = pd.to_datetime(matrix['NoteDate'])

# %%
def icd_received_within_6_months(row, icd_df):
    patient_id = row['BDSPPatientID']
    note_date = row['NoteDate']
    start_date = note_date - pd.DateOffset(months=6)
    end_date = note_date + pd.DateOffset(months=6)
    
    patient_icd_df = icd_df[icd_df['BDSPPatientID'] == patient_id]
    return 1 if ((patient_icd_df['ICDDate'] >= start_date) & 
            (patient_icd_df['ICDDate'] <= end_date)).any() else 0

# Apply the function to each row in the matrix
matrix['ICD'] = matrix.apply(icd_received_within_6_months, axis=1, icd_df=icd_df)

matrix.head()
# Out:
#    BDSPPatientID   NoteDate                                  NoteTitle  \
# 0      115883980 2018-04-14  Notes_13414009311_1956375582_20180414.txt
# 1      116483510 2022-05-12  Notes_13622415618_8165687294_20220512.txt
# 2      150009858 2013-08-29   Notes_1129868316_2608699887_20130829.txt
# 3      150009896 2022-02-04   Notes_1129868625_2609280946_20220204.txt
# 4      116023288 2022-01-03  Notes_13528991310_6365444126_20220103.txt
#
#                                                 text hospital  annot  ICD
# 0    Physician ***** *****       Admit date: ****...      MGB      1    1
# 1    Physician ***** *****       Admit date: ****...      MGB      0    0
# 2  \n\nNote Date: *****/*****/*****\n\nNote Type:...    BIDMC      1    1
# 3  \n\nNote Date: *****/*****/*****  Time: 0813\n...    BIDMC      1    1
# 4      *****  *****    ***** Medical Psychiatry D...      MGB      0    0

# %%
matrix.to_csv('1_matrix_ICD_feature_training.csv', index=False)
