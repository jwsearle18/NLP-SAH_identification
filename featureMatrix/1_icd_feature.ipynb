# %%
import pandas as pd
from thunderpack import ThunderReader
from tqdm import tqdm
import re
import glob

# %% [markdown]
# # Create Feature Matrix Format
# - include info from cohort, add annotations column
# - add icd feature which includes those with pos ICD +/- 6 months of Note Date

# %%
# create basic frame for feature matrix
# create list of all patient IDs that were used in annotation
cohort = pd.read_csv('/home/jsearle/bigDrive/NAX/NLP-SAH_identification/test&trainCohorts/combined_cohort_train.csv')

# read in annotations
annotations = pd.read_csv('/home/jsearle/bigDrive/NAX/NLP-SAH_identification/annotationTools/cleanAnnotations/full_annotations_final.csv')

print(len(cohort))
print(len(annotations))
# Out:
# 1548
# 3096

# %%
startMatrix = cohort.merge(annotations, left_on='BDSPPatientID', right_on='empi', how='inner')
print(len(startMatrix))
startMatrix.head()
# Out:
# 1548
#    BDSPPatientID             NoteDate  \
# 0      117032881  2021-09-29 00:00:00
# 1      120402560           2021-09-01
# 2      111454037           2023-11-15
# 3      121582882  2018-10-10 00:00:00
# 4      111678728  2016-12-29 00:00:00
#
#                                     NoteTitle  \
# 0   Notes_13689094716_7824448998_20210929.txt
# 1   Notes_13598482458_7493034182_20210901.txt
# 2  Notes_13666481048_10665439216_20231115.txt
# 3   Notes_13329742924_1945106714_20181010.txt
# 4   Notes_13278714866_1420969733_20161229.txt
#
#                                                 text       empi  annot
# 0    Physician ***** *****       Admit date: ****...  117032881      0
# 1    Physician ***** *****       Admit date: ****...  120402560      0
# 2           Discharge Summary   Name: ***** *****...  111454037      0
# 3    Physician ***** *****       Admit date: ****...  121582882      0
# 4    Physician ***** *****       Admit date: ****...  111678728      0

# %%
matrix = startMatrix.drop(columns=['empi'])
matrix.head()
# Out:
#    BDSPPatientID             NoteDate  \
# 0      117032881  2021-09-29 00:00:00
# 1      120402560           2021-09-01
# 2      111454037           2023-11-15
# 3      121582882  2018-10-10 00:00:00
# 4      111678728  2016-12-29 00:00:00
#
#                                     NoteTitle  \
# 0   Notes_13689094716_7824448998_20210929.txt
# 1   Notes_13598482458_7493034182_20210901.txt
# 2  Notes_13666481048_10665439216_20231115.txt
# 3   Notes_13329742924_1945106714_20181010.txt
# 4   Notes_13278714866_1420969733_20161229.txt
#
#                                                 text  annot
# 0    Physician ***** *****       Admit date: ****...      0
# 1    Physician ***** *****       Admit date: ****...      0
# 2           Discharge Summary   Name: ***** *****...      0
# 3    Physician ***** *****       Admit date: ****...      0
# 4    Physician ***** *****       Admit date: ****...      0

# %% [markdown]
# ## MGB ICDs

# %%
path = '/home/jsearle/bigDrive/NAX/NLP-SAH_identification/cohortExtractionPipeline/MGB/CSVs/'

patientIDs = matrix['BDSPPatientID']
print(len(patientIDs))
# Out:
# 1548

# %%
csv_files = glob.glob(path + "filtered_ICD_partition_*.csv")

# %%
filtered_dfs = []

for file in tqdm(csv_files):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file)
    
    # Filter the DataFrame to include only rows with matching BDSPPatientID
    filtered_df = df[df['BDSPPatientID'].isin(patientIDs)]
    
    # Append the filtered DataFrame to the list
    filtered_dfs.append(filtered_df)

# Concatenate all filtered DataFrames into one
relevantPatientICDs = pd.concat(filtered_dfs, ignore_index=True)

relevantPatientICDs.head()
# Out:
# 100%|██████████| 511/511 [01:48<00:00,  4.71it/s]
#    BDSPEncounterID  EncounterLineNBR  BDSPPatientID  \
# 0     1.356705e+10                 1    117562273.0
# 1     1.328063e+10                 2    122057217.0
# 2     1.351968e+10                 1    118601252.0
# 3     1.342068e+10                 1    118129222.0
# 4     1.329248e+10                 1    120791202.0
#
#              ShiftedContactDTS  ICDLineNBR   ICDCD  \
# 0  2023-07-11 00:00:00.0000000         1.0   351.9
# 1  2018-02-26 00:00:00.0000000         1.0  787.20
# 2  2021-04-30 00:00:00.0000000         1.0  V65.49
# 3  2019-08-21 00:00:00.0000000         2.0   571.5
# 4  2016-11-10 00:00:00.0000000         1.0   401.9
#
#                                           ICDDSC  \
# 0             Facial nerve disorder, unspecified
# 1                         Dysphagia, unspecified
# 2                     Other specified counseling
# 3  Cirrhosis of liver without mention of alcohol
# 4             Unspecified essential hypertension
#
#                                          DiagnosisNM DiagnosisDSC  \
# 0                              Facial nerve disorder          NaN
# 1                        Dysphagia, unspecified type          NaN
# 2                Counseling and coordination of care          NaN
# 3  Liver cirrhosis secondary to nonalcoholic stea...          NaN
# 4                             Essential hypertension          NaN
#
#   PrimaryDiagnosisFLG DiagnosisChronicFLG             ShiftedUpdateDTS  \
# 0                   Y                   N  2023-07-11 20:10:00.0000000
# 1                   N                   N  2023-11-07 17:34:00.0000000
# 2                   Y                   N  2021-05-01 11:00:00.0000000
# 3                   N                   N  2019-09-02 15:07:00.0000000
# 4                   Y                   N  2022-04-24 20:18:00.0000000
#
#    DiagnosisLinkedProblemID          BDSPLastModifiedDTS code_type
# 0                       NaN  2022-09-25 07:01:48.2070000       ICD
# 1                41582426.0  2023-08-15 18:43:12.0060000       ICD
# 2                27553194.0  2022-04-27 14:08:48.7770000       ICD
# 3                76499212.0  2022-04-27 12:58:36.0030000       ICD
# 4                20902954.0  2023-08-15 18:01:15.4060000       ICD

# %%
# Save the combined DataFrame to a new CSV file
relevantPatientICDs.to_csv("MGBrelevantPatientICDs.csv", index=False)

# %% [markdown]
# ## BIDMC ICDs

# %%
path = '/home/jsearle/bigDrive/NAX/NLP-SAH_identification/cohortExtractionPipeline/BIDMC/CSVs/'

patientIDs = matrix['BDSPPatientID']
print(len(patientIDs))
# Out:
# 1548

# %%
csv_files = glob.glob(path + "filtered_ICD_partition_*.csv")

# %%
filtered_dfs = []

for file in tqdm(csv_files):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file)
    
    # Filter the DataFrame to include only rows with matching BDSPPatientID
    filtered_df = df[df['BDSPPatientID'].isin(patientIDs)]
    
    # Append the filtered DataFrame to the list
    filtered_dfs.append(filtered_df)

# Concatenate all filtered DataFrames into one
relevantPatientICDs = pd.concat(filtered_dfs, ignore_index=True)

relevantPatientICDs.head()
# Out:
#   8%|▊         | 3/36 [00:06<01:08,  2.07s/it]/tmp/ipykernel_16843/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  11%|█         | 4/36 [00:08<01:03,  1.99s/it]/tmp/ipykernel_16843/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  14%|█▍        | 5/36 [00:10<01:02,  2.02s/it]/tmp/ipykernel_16843/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  22%|██▏       | 8/36 [00:16<00:57,  2.05s/it]/tmp/ipykernel_16843/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  33%|███▎      | 12/36 [00:25<00:51,  2.13s/it]/tmp/ipykernel_16843/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  50%|█████     | 18/36 [00:36<00:34,  1.93s/it]/tmp/ipykernel_16843/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#  81%|████████  | 29/36 [00:59<00:13,  1.94s/it]/tmp/ipykernel_16843/778544000.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# 100%|██████████| 36/36 [01:12<00:00,  2.02s/it]
#    BDSPPatientID  BDSPEncounterID  DiagnosisSequenceNumber DiagnosisCode  \
# 0      151039569       1051843626                        1       C50311
# 1      151041279       1052728849                        1       C7951
# 2      151041279       1052728849                        2       G939
# 3      151039569       1051845284                        1       C50311
# 4      151041279       1052733141                        1       C7951
#
#   DiagnosisPoaInd DiagnosisCodeWithDots                     ShortDescription  \
# 0             NaN               C50.311  MAL NEO LW-INNER QUAD RT
# 1             NaN                C79.51  SECONDARY MALIGNANT NEOP
# 2             NaN                 G93.9  DISORDER OF BRAIN UNSPEC
# 3             NaN               C50.311  MAL NEO LW-INNER QUAD RT
# 4             NaN                C79.51  SECONDARY MALIGNANT NEOP
#
#                                      LongDescription DiagnosisType  \
# 0  MALIG NEOPLM OF LOWER-INNER QUADRANT OF RIGHT ...         ICD10
# 1  SECONDARY MALIGNANT NEOPLASM OF BONE          ...         ICD10
# 2  DISORDER OF BRAIN, UNSPECIFIED                ...         ICD10
# 3  MALIG NEOPLM OF LOWER-INNER QUADRANT OF RIGHT ...         ICD10
# 4  SECONDARY MALIGNANT NEOPLASM OF BONE          ...         ICD10
#
#   AdmissionDate DischargeDate          BDSPLastModifiedDTS code_type
# 0    2016-11-21    2016-11-21  2023-07-19 19:09:12.4626110     ICD10
# 1    2018-07-01    2018-07-01  2023-07-19 19:10:23.4213520     ICD10
# 2    2018-07-01    2018-07-01  2023-07-19 19:10:23.4213520     ICD10
# 3    2016-11-22    2016-11-22  2023-07-19 19:09:12.4626110     ICD10
# 4    2018-07-03    2018-07-03  2023-07-19 19:10:23.4213520     ICD10

# %%
# Save the combined DataFrame to a new CSV file
relevantPatientICDs.to_csv("BIDMCrelevantPatientICDs.csv", index=False)

# %% [markdown]
# # Create new csv that filters by ICD code
# ### MGB First

# %%
MGBrelevantPatientICDs = pd.read_csv("MGBrelevantPatientICDs.csv")
BIDMCrelevantPatientICDs = pd.read_csv("BIDMCrelevantPatientICDs.csv")

# %%
code_regex = '^(I60|430)'

MGBrelevantPatientICDs = MGBrelevantPatientICDs.dropna(subset=['ICDCD'])

allPosICDsMGB = MGBrelevantPatientICDs[MGBrelevantPatientICDs['ICDCD'].str.match(code_regex)]

allPosICDsMGB.head()
# Out:
#      BDSPEncounterID  EncounterLineNBR  BDSPPatientID  \
# 217     1.372123e+10                 4    121501383.0
# 225     1.361430e+10                 2    113797450.0
# 251     1.354392e+10                 3    111244917.0
# 484     1.368526e+10                 1    116587087.0
# 525     1.344095e+10                 2    113252439.0
#
#                ShiftedContactDTS  ICDLineNBR ICDCD                   ICDDSC  \
# 217  2022-07-03 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 225  2021-06-22 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 251  2021-02-07 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 484  2022-10-20 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
# 525  2018-04-04 00:00:00.0000000         1.0   430  Subarachnoid hemorrhage
#
#                                  DiagnosisNM DiagnosisDSC PrimaryDiagnosisFLG  \
# 217                  Subarachnoid hemorrhage          NaN                   N
# 225  Ruptured (congenital) cerebral aneurysm          NaN                   N
# 251            SAH (subarachnoid hemorrhage)          NaN                   N
# 484            SAH (subarachnoid hemorrhage)          NaN                   Y
# 525                  Subarachnoid hemorrhage          NaN                   N
#
#     DiagnosisChronicFLG             ShiftedUpdateDTS  \
# 217                   N  2022-07-04 23:08:00.0000000
# 225                   N  2021-06-22 18:14:00.0000000
# 251                   N  2021-02-07 17:13:00.0000000
# 484                   N  2022-11-17 13:20:00.0000000
# 525                   N  2022-08-25 19:37:00.0000000
#
#      DiagnosisLinkedProblemID          BDSPLastModifiedDTS code_type
# 217               127299861.0  2022-09-15 07:00:26.8080000       ICD
# 225               112494133.0  2022-06-13 17:43:46.0660000       ICD
# 251                85747190.0  2022-04-27 13:40:53.7930000       ICD
# 484               124551050.0  2022-06-13 17:47:33.6620000       ICD
# 525                54503085.0  2023-08-16 01:13:14.4420000       ICD

# %%
BIDMCrelevantPatientICDs = BIDMCrelevantPatientICDs.dropna(subset=['DiagnosisCodeWithDots'])

allPosICDsBIDMC = BIDMCrelevantPatientICDs[BIDMCrelevantPatientICDs['DiagnosisCodeWithDots'].str.match(code_regex)]

allPosICDsBIDMC.head()
# Out:
#      BDSPPatientID  BDSPEncounterID  DiagnosisSequenceNumber DiagnosisCode  \
# 534      151055839        134384936                        1       I6012
# 616      151053565        134426070                        2       I609
# 758      151066006        134656049                        1       I604
# 930      151055839        984158717                        1       I609
# 978      151055839        982329054                        1       I609
#
#     DiagnosisPoaInd DiagnosisCodeWithDots  \
# 534               Y                I60.12
# 616               N                 I60.9
# 758               Y                 I60.4
# 930             NaN                 I60.9
# 978             NaN                 I60.9
#
#                         ShortDescription  \
# 534  NONTRAUM SA HEMOR LT MID
# 616  NONTRAUMATIC SUBARACH HE
# 758  NONTRAUM SA HEMORR BASIL
# 930  NONTRAUMATIC SUBARACH HE
# 978  NONTRAUMATIC SUBARACH HE
#
#                                        LongDescription DiagnosisType  \
# 534  NTRM SUBARACH HEMORRHAGE FROM LEFT MIDDLE CERE...         ICD10
# 616  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
# 758  NONTRAUMATIC SUBARACHNOID HEMORRHAGE FROM BASI...         ICD10
# 930  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
# 978  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
#
#     AdmissionDate DischargeDate          BDSPLastModifiedDTS code_type
# 534    2018-05-18    2018-06-05  2023-07-19 19:10:23.4213520     ICD10
# 616    2019-01-30    2019-02-11  2023-07-19 19:10:23.4213520     ICD10
# 758    2021-03-30    2021-04-11  2023-07-19 19:11:59.3749140     ICD10
# 930    2018-09-16    2018-09-16  2023-07-19 19:10:23.4213520     ICD10
# 978    2018-07-10    2018-07-10  2023-07-19 19:10:23.4213520     ICD10

# %%
allPosICDsMGB.to_csv("allPosICDsMGB.csv", index=False)
allPosICDsBIDMC.to_csv("allPosICDsBIDMC.csv", index=False)

# %% [markdown]
# ## Now adding feature for ICD code received 6 months +/- the NoteDate

# %%
# Rename the date columns to a common name
allPosICDsMGB = allPosICDsMGB.rename(columns={'ShiftedContactDTS': 'ICDDate'})
allPosICDsBIDMC = allPosICDsBIDMC.rename(columns={'AdmissionDate': 'ICDDate'})

# %%
allPosICDsMGB.head()
# Out:
#      BDSPEncounterID  EncounterLineNBR  BDSPPatientID    ICDDate  ICDLineNBR  \
# 217     1.372123e+10                 4    121501383.0 2022-07-03         1.0
# 225     1.361430e+10                 2    113797450.0 2021-06-22         1.0
# 251     1.354392e+10                 3    111244917.0 2021-02-07         1.0
# 484     1.368526e+10                 1    116587087.0 2022-10-20         1.0
# 525     1.344095e+10                 2    113252439.0 2018-04-04         1.0
#
#     ICDCD                   ICDDSC                              DiagnosisNM  \
# 217   430  Subarachnoid hemorrhage                  Subarachnoid hemorrhage
# 225   430  Subarachnoid hemorrhage  Ruptured (congenital) cerebral aneurysm
# 251   430  Subarachnoid hemorrhage            SAH (subarachnoid hemorrhage)
# 484   430  Subarachnoid hemorrhage            SAH (subarachnoid hemorrhage)
# 525   430  Subarachnoid hemorrhage                  Subarachnoid hemorrhage
#
#     DiagnosisDSC PrimaryDiagnosisFLG DiagnosisChronicFLG  \
# 217          NaN                   N                   N
# 225          NaN                   N                   N
# 251          NaN                   N                   N
# 484          NaN                   Y                   N
# 525          NaN                   N                   N
#
#                 ShiftedUpdateDTS  DiagnosisLinkedProblemID  \
# 217  2022-07-04 23:08:00.0000000               127299861.0
# 225  2021-06-22 18:14:00.0000000               112494133.0
# 251  2021-02-07 17:13:00.0000000                85747190.0
# 484  2022-11-17 13:20:00.0000000               124551050.0
# 525  2022-08-25 19:37:00.0000000                54503085.0
#
#              BDSPLastModifiedDTS code_type
# 217  2022-09-15 07:00:26.8080000       ICD
# 225  2022-06-13 17:43:46.0660000       ICD
# 251  2022-04-27 13:40:53.7930000       ICD
# 484  2022-06-13 17:47:33.6620000       ICD
# 525  2023-08-16 01:13:14.4420000       ICD

# %%
allPosICDsBIDMC.head()
# Out:
#      BDSPPatientID  BDSPEncounterID  DiagnosisSequenceNumber DiagnosisCode  \
# 534      151055839        134384936                        1       I6012
# 616      151053565        134426070                        2       I609
# 758      151066006        134656049                        1       I604
# 930      151055839        984158717                        1       I609
# 978      151055839        982329054                        1       I609
#
#     DiagnosisPoaInd DiagnosisCodeWithDots  \
# 534               Y                I60.12
# 616               N                 I60.9
# 758               Y                 I60.4
# 930             NaN                 I60.9
# 978             NaN                 I60.9
#
#                         ShortDescription  \
# 534  NONTRAUM SA HEMOR LT MID
# 616  NONTRAUMATIC SUBARACH HE
# 758  NONTRAUM SA HEMORR BASIL
# 930  NONTRAUMATIC SUBARACH HE
# 978  NONTRAUMATIC SUBARACH HE
#
#                                        LongDescription DiagnosisType  \
# 534  NTRM SUBARACH HEMORRHAGE FROM LEFT MIDDLE CERE...         ICD10
# 616  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
# 758  NONTRAUMATIC SUBARACHNOID HEMORRHAGE FROM BASI...         ICD10
# 930  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
# 978  NONTRAUMATIC SUBARACHNOID HEMORRHAGE, UNSPECIF...         ICD10
#
#        ICDDate DischargeDate          BDSPLastModifiedDTS code_type
# 534 2018-05-18    2018-06-05  2023-07-19 19:10:23.4213520     ICD10
# 616 2019-01-30    2019-02-11  2023-07-19 19:10:23.4213520     ICD10
# 758 2021-03-30    2021-04-11  2023-07-19 19:11:59.3749140     ICD10
# 930 2018-09-16    2018-09-16  2023-07-19 19:10:23.4213520     ICD10
# 978 2018-07-10    2018-07-10  2023-07-19 19:10:23.4213520     ICD10

# %%
allPosICDsMGB['ICDDate'] = pd.to_datetime(allPosICDsMGB['ICDDate'])
allPosICDsBIDMC['ICDDate'] = pd.to_datetime(allPosICDsBIDMC['ICDDate'])

# %%
icd_df = pd.concat([allPosICDsMGB, allPosICDsBIDMC], ignore_index=True)

# %%
matrix = startMatrix

# %%
def parse_dates(date_str):
    for fmt in ('%Y-%m-%d %H:%M:%S.%f', '%Y-%m-%d %H:%M:%S', '%Y-%m-%d'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue
    # If all formats fail, return NaT
    return pd.NaT

# Apply the custom function to convert dates
matrix['NoteDate'] = matrix['NoteDate'].apply(parse_dates)
matrix.head()
# Out:
#    BDSPPatientID   NoteDate                                   NoteTitle  \
# 0      117032881 2021-09-29   Notes_13689094716_7824448998_20210929.txt
# 1      120402560 2021-09-01   Notes_13598482458_7493034182_20210901.txt
# 2      111454037 2023-11-15  Notes_13666481048_10665439216_20231115.txt
# 3      121582882 2018-10-10   Notes_13329742924_1945106714_20181010.txt
# 4      111678728 2016-12-29   Notes_13278714866_1420969733_20161229.txt
#
#                                                 text       empi  annot
# 0    Physician ***** *****       Admit date: ****...  117032881      0
# 1    Physician ***** *****       Admit date: ****...  120402560      0
# 2           Discharge Summary   Name: ***** *****...  111454037      0
# 3    Physician ***** *****       Admit date: ****...  121582882      0
# 4    Physician ***** *****       Admit date: ****...  111678728      0

# %%
matrix = matrix.drop(columns=['empi'])
matrix.head()
# Out:
#    BDSPPatientID   NoteDate                                   NoteTitle  \
# 0      117032881 2021-09-29   Notes_13689094716_7824448998_20210929.txt
# 1      120402560 2021-09-01   Notes_13598482458_7493034182_20210901.txt
# 2      111454037 2023-11-15  Notes_13666481048_10665439216_20231115.txt
# 3      121582882 2018-10-10   Notes_13329742924_1945106714_20181010.txt
# 4      111678728 2016-12-29   Notes_13278714866_1420969733_20161229.txt
#
#                                                 text  annot
# 0    Physician ***** *****       Admit date: ****...      0
# 1    Physician ***** *****       Admit date: ****...      0
# 2           Discharge Summary   Name: ***** *****...      0
# 3    Physician ***** *****       Admit date: ****...      0
# 4    Physician ***** *****       Admit date: ****...      0

# %%
matrix['NoteDate'] = pd.to_datetime(matrix['NoteDate'])

# %%
def icd_received_within_6_months(row, icd_df):
    patient_id = row['BDSPPatientID']
    note_date = row['NoteDate']
    start_date = note_date - pd.DateOffset(months=6)
    end_date = note_date + pd.DateOffset(months=6)
    
    patient_icd_df = icd_df[icd_df['BDSPPatientID'] == patient_id]
    return 1 if ((patient_icd_df['ICDDate'] >= start_date) & 
            (patient_icd_df['ICDDate'] <= end_date)).any() else 0

# Apply the function to each row in the matrix
matrix['ICD'] = matrix.apply(icd_received_within_6_months, axis=1, icd_df=icd_df)

matrix.head()
# Out:
#    BDSPPatientID   NoteDate                                   NoteTitle  \
# 0      117032881 2021-09-29   Notes_13689094716_7824448998_20210929.txt
# 1      120402560 2021-09-01   Notes_13598482458_7493034182_20210901.txt
# 2      111454037 2023-11-15  Notes_13666481048_10665439216_20231115.txt
# 3      121582882 2018-10-10   Notes_13329742924_1945106714_20181010.txt
# 4      111678728 2016-12-29   Notes_13278714866_1420969733_20161229.txt
#
#                                                 text  annot  ICD
# 0    Physician ***** *****       Admit date: ****...      0    0
# 1    Physician ***** *****       Admit date: ****...      0    0
# 2           Discharge Summary   Name: ***** *****...      0    0
# 3    Physician ***** *****       Admit date: ****...      0    0
# 4    Physician ***** *****       Admit date: ****...      0    0

# %%
matrix.to_csv('matrix_ICD_feature_training.csv', index=False)
