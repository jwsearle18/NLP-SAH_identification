# %% [markdown]
# # Filter by those who don't have SAH ICD code
# The kernel won't be able to handle the ICD- cohort, so I'll change the order and filter by discharge summary first, then by negative SAH ICD code.  Then I will do randomized selection of the same number of ICD+ and include notes text.

# %%
# imports
import pandas as pd
from thunderpack import ThunderReader
from tqdm import tqdm
import re
import os

# %%
#filter all notes to only include discharge summaries
# year = 2013
# dfs = []
# for i in range(0, 12):
#     df = pd.read_csv(f'/home/jsearle/bigDrive/Dropbox/zz_EHR_Thunderpacks/MGB/MGB_Deidentified_Notes_March12th2024/mgb_notes_{year + i}_metadata.csv')
#     df = df[df['InpatientNoteTypeDSC'] == 'Discharge Summary']
#     dfs.append(df)

# %%
# show number of total discharge summaries then show example
# discharge_summaries = pd.concat(dfs, axis=0, ignore_index=True)
# print(len(discharge_summaries))
# discharge_summaries.head()

# %%
output_dir = '/home/jsearle/bigDrive/NAX/NLP-SAH_identification/code/newPipeline/MGB/6csv'

# Concatenate all filtered CSV files
all_files = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if f.startswith('discharge_summaries_')]
discharge_summaries = pd.concat((pd.read_csv(f) for f in all_files), axis=0, ignore_index=True)

# Show number of total discharge summaries
print(len(discharge_summaries))

# Show example
discharge_summaries.head()
# Out:
# 539579
#   BDSPPatientID ContactDate InpatientNoteTypeDSC  \
# 0     121552394    20190106    Discharge Summary
# 1     121552394    20190106    Discharge Summary
# 2     121210730    20190105    Discharge Summary
# 3     118988577    20190114    Discharge Summary
# 4     116506911    20190118    Discharge Summary
#
#                             DeidentifiedName
# 0  Notes_13407429969_1897463845_20190106.txt
# 1  Notes_13407429969_1897464004_20190106.txt
# 2  Notes_13338301602_1897145379_20190105.txt
# 3  Notes_13351931736_1915990662_20190114.txt
# 4  Notes_13339873460_1914565554_20190118.txt

# %%
#filter by unique patient ID
discharged_patients = set(discharge_summaries['BDSPPatientID'])
print(len(discharged_patients))
# Out:
# 69684

# %% [markdown]
# ### Randomization
#  - Setting seed (25) just to be able to reproduce results

# %%
rand_DS_comp = discharge_summaries.sample(frac=1, random_state=25).reset_index(drop=True)
rand_DS_comp.head()
# Out:
#   BDSPPatientID ContactDate InpatientNoteTypeDSC  \
# 0     115620551    20150304    Discharge Summary
# 1     114670821    20140924    Discharge Summary
# 2     112187363    20150303    Discharge Summary
# 3     117169043    20141206    Discharge Summary
# 4     122816355    20160824    Discharge Summary
#
#                             DeidentifiedName
# 0   Notes_13177882086_440619766_20150304.txt
# 1   Notes_13211093280_453355769_20140924.txt
# 2   Notes_13275669540_440764122_20150303.txt
# 3   Notes_13201865993_476529782_20141206.txt
# 4  Notes_13404964868_1469502913_20160824.txt

# %%
rand_DS = rand_DS_comp.drop_duplicates(subset='BDSPPatientID', keep='first')
print(len(rand_DS))
# Out:
# 69684

# %% [markdown]
# ### Combine with ICD table
#  - I will be looking at all ICD codes within the month leading up to the date of the discharge summary
#  - Check the format of the dates
#  - Merge based on patient ID and date

# %%
output_dir = '/home/jsearle/bigDrive/NAX/NLP-SAH_identification/code/newPipeline/MGB/6csv'

all_files = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if f.startswith('filtered_ICD_partition_')]
final_df = pd.concat((pd.read_csv(f) for f in all_files), axis=0, ignore_index=True)

print(len(final_df))

# Show example
final_df.head()
# Out:
# 27129594
#    BDSPEncounterID  EncounterLineNBR  BDSPPatientID  \
# 0     1.362650e+10                 1    118474377.0
# 1     1.358150e+10                 3    122336922.0
# 2     1.342783e+10                11    120522435.0
# 3     1.335468e+10                 3    115980947.0
# 4     1.372510e+10                 1    114241241.0
#
#              ShiftedContactDTS  ICDLineNBR   ICDCD  \
# 0  2023-05-20 00:00:00.0000000         1.0   157.1
# 1  2022-08-06 00:00:00.0000000         1.0  788.99
# 2  2018-09-30 00:00:00.0000000         1.0  278.01
# 3  2018-05-10 00:00:00.0000000         1.0  309.81
# 4  2023-01-20 00:00:00.0000000         1.0   465.9
#
#                                               ICDDSC  \
# 0             Malignant neoplasm of body of pancreas
# 1            Other symptoms involving urinary system
# 2                                     Morbid obesity
# 3                      Posttraumatic stress disorder
# 4  Acute upper respiratory infections of unspecif...
#
#                                          DiagnosisNM DiagnosisDSC  \
# 0             Malignant neoplasm of body of pancreas          NaN
# 1                       Lower urinary tract symptoms          NaN
# 2  Class 2 severe obesity due to excess calories ...          NaN
# 3                      Posttraumatic stress disorder          NaN
# 4                                          Viral URI          NaN
#
#   PrimaryDiagnosisFLG DiagnosisChronicFLG             ShiftedUpdateDTS  \
# 0                   Y                   N  2023-05-20 13:25:00.0000000
# 1                   N                   N  2022-08-08 03:51:00.0000000
# 2                   N                   N  2019-01-09 10:12:00.0000000
# 3                   N                   N  2024-01-20 19:05:00.0000000
# 4                   Y                   N  2023-01-20 11:45:00.0000000
#
#    DiagnosisLinkedProblemID          BDSPLastModifiedDTS code_type
# 0               135026244.0  2023-08-16 02:47:04.0620000       ICD
# 1                96060426.0  2022-04-27 13:40:53.7930000       ICD
# 2                33794057.0  2022-04-27 14:57:52.3070000       ICD
# 3                18320222.0  2023-08-15 19:01:32.7250000       ICD
# 4                       NaN  2023-08-16 04:41:57.7350000       ICD

# %%
#Take random sample of 500000 to make it smaller and easier to work with.

final_df = final_df.sample(n=500000, replace=False, random_state=1)

# %%
#filter by ICD-
code_regex = "^(?!I60|430).*"
filtered_final_df = final_df[final_df['ICDCD'].astype(str).str.match(code_regex, flags=re.I)]
del final_df

# %%
# change from string to datetime
filtered_final_df['ShiftedContactDTS'] = pd.to_datetime(filtered_final_df['ShiftedContactDTS'])
print(filtered_final_df['ShiftedContactDTS'][2])
print(type(filtered_final_df['ShiftedContactDTS'][2]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/NAX/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 # change from string to datetime
#       2 filtered_final_df['ShiftedContactDTS'] = pd.to_datetime(filtered_final_df['ShiftedContactDTS'])
# ----> 3 print(filtered_final_df['ShiftedContactDTS'][2])
#       4 print(type(filtered_final_df['ShiftedContactDTS'][2]))
#
# File ~/miniconda3/envs/NAX/lib/python3.12/site-packages/pandas/core/series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
#    1115 # (We will iterate through the generator there to check for slices)
#    1116 if is_iterator(key):
#
# File ~/miniconda3/envs/NAX/lib/python3.12/site-packages/pandas/core/series.py:1228, in Series._get_value(self, label, takeable)
#    1225     return self._values[label]
#    1227 # Similar to Index.get_value, but we do not fall back to positional
# -> 1228 loc = self.index.get_loc(label)
#    1230 if is_integer(loc):
#    1231     return self._values[loc]
#
# File ~/miniconda3/envs/NAX/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 2

# %%
rand_DS.loc[:, 'ContactDate'] = pd.to_datetime(rand_DS['ContactDate'], format='%Y%m%d')
print(rand_DS['ContactDate'][2])
print(type(rand_DS['ContactDate'][2]))
# Out:
# 2015-03-03 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
merged_df = pd.merge(filtered_final_df, rand_DS, on='BDSPPatientID')

# %%
merged_df.head()
# Out:
#    BDSPEncounterID  EncounterLineNBR BDSPPatientID ShiftedContactDTS  \
# 0     1.362650e+10                 1   118474377.0        2023-05-20
# 1     1.358150e+10                 3   122336922.0        2022-08-06
# 2     1.342783e+10                11   120522435.0        2018-09-30
# 3     1.335468e+10                 3   115980947.0        2018-05-10
# 4     1.372510e+10                 1   114241241.0        2023-01-20
#
#    ICDLineNBR   ICDCD                                             ICDDSC  \
# 0         1.0   157.1             Malignant neoplasm of body of pancreas
# 1         1.0  788.99            Other symptoms involving urinary system
# 2         1.0  278.01                                     Morbid obesity
# 3         1.0  309.81                      Posttraumatic stress disorder
# 4         1.0   465.9  Acute upper respiratory infections of unspecif...
#
#                                          DiagnosisNM DiagnosisDSC  \
# 0             Malignant neoplasm of body of pancreas          NaN
# 1                       Lower urinary tract symptoms          NaN
# 2  Class 2 severe obesity due to excess calories ...          NaN
# 3                      Posttraumatic stress disorder          NaN
# 4                                          Viral URI          NaN
#
#   PrimaryDiagnosisFLG DiagnosisChronicFLG             ShiftedUpdateDTS  \
# 0                   Y                   N  2023-05-20 13:25:00.0000000
# 1                   N                   N  2022-08-08 03:51:00.0000000
# 2                   N                   N  2019-01-09 10:12:00.0000000
# 3                   N                   N  2024-01-20 19:05:00.0000000
# 4                   Y                   N  2023-01-20 11:45:00.0000000
#
#    DiagnosisLinkedProblemID          BDSPLastModifiedDTS code_type  \
# 0               135026244.0  2023-08-16 02:47:04.0620000       ICD
# 1                96060426.0  2022-04-27 13:40:53.7930000       ICD
# 2                33794057.0  2022-04-27 14:57:52.3070000       ICD
# 3                18320222.0  2023-08-15 19:01:32.7250000       ICD
# 4                       NaN  2023-08-16 04:41:57.7350000       ICD
#
#            ContactDate InpatientNoteTypeDSC  \
# 0  2019-11-26 00:00:00    Discharge Summary
# 1  2023-12-05 00:00:00    Discharge Summary
# 2  2015-12-16 00:00:00    Discharge Summary
# 3  2016-04-10 00:00:00    Discharge Summary
# 4  2015-02-04 00:00:00    Discharge Summary
#
#                             DeidentifiedName
# 0  Notes_13385975835_2644414416_20191126.txt
# 1  Notes_13705144828_9349774420_20231205.txt
# 2   Notes_13310872420_756262157_20151216.txt
# 3   Notes_13254167247_450575706_20160410.txt
# 4   Notes_13264279068_433538463_20150204.txt

# %%
# +/- one month
merged_df_one_month = merged_df[(merged_df['ShiftedContactDTS'] >= merged_df['ContactDate'] - pd.DateOffset(months=1)) & 
                                (merged_df['ShiftedContactDTS'] <= merged_df['ContactDate'] + pd.DateOffset(months=1))]

# %%
print(len(merged_df_one_month))
merged_df_one_month.head()
# Out:
# 1087
#           BDSPEncounterID  EncounterLineNBR BDSPPatientID ShiftedContactDTS  \
# 22669430     1.361330e+10                 1   114216511.0        2022-03-30
# 18676571     1.367312e+10                 1   115825493.0        2024-04-06
# 9654591      1.372720e+10                 8   122397082.0        2021-12-05
# 13371446     1.337757e+10                 2   117886365.0        2018-05-21
# 18924275     1.359266e+10                11   112990024.0        2021-11-10
#
#           ICDLineNBR   ICDCD  \
# 22669430         2.0  E933.1
# 18676571         1.0  596.54
# 9654591          1.0  V65.49
# 13371446         1.0   473.1
# 18924275         1.0  R09.02
#
#                                                      ICDDSC  \
# 22669430  Antineoplastic and immunosuppressive drugs cau...
# 18676571                             Neurogenic bladder NOS
# 9654591                          Other specified counseling
# 13371446                          Chronic frontal sinusitis
# 18924275                                          Hypoxemia
#
#                                    DiagnosisNM DiagnosisDSC  \
# 22669430      Chemotherapy induced neutropenia          NaN
# 18676571   Neurogenic urinary bladder disorder          NaN
# 9654591   Goals of care, counseling/discussion          NaN
# 13371446             Chronic frontal sinusitis          NaN
# 18924275                               Hypoxia          NaN
#
#          PrimaryDiagnosisFLG DiagnosisChronicFLG             ShiftedUpdateDTS  \
# 22669430                   N                   N  2023-12-22 11:23:00.0000000
# 18676571                   Y                   N  2024-04-06 19:14:00.0000000
# 9654591                    N                   N  2021-12-06 01:23:00.0000000
# 13371446                   N                   N  2024-01-26 18:17:00.0000000
# 18924275                   N                   N  2021-11-26 13:18:00.0000000
#
#           DiagnosisLinkedProblemID          BDSPLastModifiedDTS code_type  \
# 22669430                       NaN  2023-08-16 01:32:06.3650000       ICD
# 18676571               131508324.0  2023-08-16 05:21:23.1540000       ICD
# 9654591                132294772.0  2022-11-04 23:30:15.4210000       ICD
# 13371446                       NaN  2023-08-15 18:53:39.1440000       ICD
# 18924275               122633658.0  2022-04-27 13:10:13.8100000       ICD
#
#                   ContactDate InpatientNoteTypeDSC  \
# 22669430  2022-03-29 00:00:00    Discharge Summary
# 18676571  2024-04-24 00:00:00    Discharge Summary
# 9654591   2021-11-10 00:00:00    Discharge Summary
# 13371446  2018-06-16 00:00:00    Discharge Summary
# 18924275  2021-12-03 00:00:00    Discharge Summary
#
#                                     DeidentifiedName
# 22669430   Notes_13612877798_6185656669_20220329.txt
# 18676571  Notes_13680450872_10025641612_20240424.txt
# 9654591    Notes_13719986847_8638533275_20211110.txt
# 13371446   Notes_13378253243_1622441108_20180616.txt
# 18924275   Notes_13592663582_7705422690_20211203.txt

# %%
columns_to_keep = ['BDSPPatientID', 'ShiftedContactDTS', 'ICDCD', 'code_type', 'ContactDate', 'DeidentifiedName']
clean_df = merged_df_one_month[columns_to_keep]
clean_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 merged_df_one_month = merged_df_one_month.sample(n=2500, replace=False, random_state=1)
#       2 columns_to_keep = ['BDSPPatientID', 'ShiftedContactDTS', 'ICDCD', 'code_type', 'ContactDate', 'DeidentifiedName']
#       3 clean_df = merged_df_one_month[columns_to_keep]
#
# File ~/miniconda3/envs/NAX/lib/python3.12/site-packages/pandas/core/generic.py:6115, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6112 if weights is not None:
#    6113     weights = sample.preprocess_weights(self, weights, axis)
# -> 6115 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6116 result = self.take(sampled_indices, axis=axis)
#    6118 if ignore_index:
#
# File ~/miniconda3/envs/NAX/lib/python3.12/site-packages/pandas/core/sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# File numpy/random/mtrand.pyx:1001, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
rename_dict = {
    'ShiftedContactDTS': 'ICD_Date', 
    'ICDCD': 'ICD', 
    'code_type': 'CodeType', 
    'ContactDate': 'NoteDate', 
    'DeidentifiedName': 'NoteTitle'
}

clean_df = clean_df.rename(columns=rename_dict)
clean_df.head()
# Out:
#          BDSPPatientID   ICD_Date     ICD CodeType             NoteDate  \
# 22669430   114216511.0 2022-03-30  E933.1      ICD  2022-03-29 00:00:00
# 18676571   115825493.0 2024-04-06  596.54      ICD  2024-04-24 00:00:00
# 9654591    122397082.0 2021-12-05  V65.49      ICD  2021-11-10 00:00:00
# 13371446   117886365.0 2018-05-21   473.1      ICD  2018-06-16 00:00:00
# 18924275   112990024.0 2021-11-10  R09.02      ICD  2021-12-03 00:00:00
#
#                                            NoteTitle
# 22669430   Notes_13612877798_6185656669_20220329.txt
# 18676571  Notes_13680450872_10025641612_20240424.txt
# 9654591    Notes_13719986847_8638533275_20211110.txt
# 13371446   Notes_13378253243_1622441108_20180616.txt
# 18924275   Notes_13592663582_7705422690_20211203.txt

# %%
new_order = ['BDSPPatientID', 'ICD_Date', 'NoteDate', 'ICD', 'CodeType', 'NoteTitle']
clean_df = clean_df[new_order]
clean_df.head()
# Out:
#          BDSPPatientID   ICD_Date             NoteDate     ICD CodeType  \
# 22669430   114216511.0 2022-03-30  2022-03-29 00:00:00  E933.1      ICD
# 18676571   115825493.0 2024-04-06  2024-04-24 00:00:00  596.54      ICD
# 9654591    122397082.0 2021-12-05  2021-11-10 00:00:00  V65.49      ICD
# 13371446   117886365.0 2018-05-21  2018-06-16 00:00:00   473.1      ICD
# 18924275   112990024.0 2021-11-10  2021-12-03 00:00:00  R09.02      ICD
#
#                                            NoteTitle
# 22669430   Notes_13612877798_6185656669_20220329.txt
# 18676571  Notes_13680450872_10025641612_20240424.txt
# 9654591    Notes_13719986847_8638533275_20211110.txt
# 13371446   Notes_13378253243_1622441108_20180616.txt
# 18924275   Notes_13592663582_7705422690_20211203.txt

# %%
print(len(clean_df))
# Out:
# 1087

# %%
clean_df.loc[:, 'ICD'] = clean_df['ICD'].astype(str)
grouped = clean_df.groupby('NoteTitle')['ICD'].apply(lambda x: ', '.join(x)).reset_index()
icd_neg_unique = clean_df.drop_duplicates(subset=['NoteTitle']).drop(columns=['ICD'])
icd_neg_unique = pd.merge(icd_neg_unique, grouped, on='NoteTitle', how='left')

# %%
print(len(icd_neg_unique))
# Out:
# 1049

# %%
#negative cohort same size as positive
cohort_neg = icd_neg_unique.sample(n=1087, replace=False, random_state=1)
print(len(cohort_neg))

# %%
cohort_neg = cohort_neg.drop(columns=['ICD_Date', 'CodeType', 'ICD'])
cohort_neg.head()
# Out:
#   BDSPPatientID             NoteDate  \
# 0   114216511.0  2022-03-29 00:00:00
# 1   115825493.0  2024-04-24 00:00:00
# 2   122397082.0  2021-11-10 00:00:00
# 3   117886365.0  2018-06-16 00:00:00
# 4   112990024.0  2021-12-03 00:00:00
#
#                                     NoteTitle
# 0   Notes_13612877798_6185656669_20220329.txt
# 1  Notes_13680450872_10025641612_20240424.txt
# 2   Notes_13719986847_8638533275_20211110.txt
# 3   Notes_13378253243_1622441108_20180616.txt
# 4   Notes_13592663582_7705422690_20211203.txt

# %%
# cohort_neg.to_csv('6_icd_minus.csv', index=False, header=True, sep=',', na_rep='NA')
